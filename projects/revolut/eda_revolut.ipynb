# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import itertools
import warnings
warnings.filterwarnings('ignore')

# %%
# For Laptop

filename1 = '/home/jovyan/work/data/revolut/rev-devices.csv'
filename2 = '/home/jovyan/work/data/revolut/rev-notifications.csv'
filename3 = '/home/jovyan/work/data/revolut/rev-transactions.csv'
filename4 = '/home/jovyan/work/data/revolut/rev-users.csv'

rev_devices = pd.read_csv(filename1)
rev_notifications = pd.read_csv(filename2)
rev_transactions = pd.read_csv(filename3)
rev_users = pd.read_csv(filename4)

# %%
df_rev_devices = rev_devices.copy()
df_rev_notifications = rev_notifications.copy()
df_rev_transactions = rev_transactions.copy()
df_rev_users = rev_users.copy()

# %% [markdown]
# # DATA PREPROCESSING

# %%
def missing_values_table(df):
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns

# %%
def unqiue_values_table(df):
    unq_val = df.nunique()
    unq_val_percent = 100 * df.nunique() / len(df)
    unq_val_table = pd.concat([unq_val, unq_val_percent], axis=1)
    unq_val_table_ren_columns = unq_val_table.rename(
    columns = {0 : 'Unique Values', 1 : '% of Total Values'})
    unq_val_table_ren_columns = unq_val_table_ren_columns[
        unq_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    'Unique Values', ascending=False).round(2)
    print ("Your selected dataframe has " + str(df.shape[0]) + " rows "       
        "and " + str(df.shape[1]) + " columns.")
    return unq_val_table_ren_columns

# %% [markdown]
# ### USERS

# %%
missing_values_table(df_rev_users)
# Out:
# Your selected dataframe has 12 columns.
# There are 2 columns that have missing values.
#                                           Missing Values  % of Total Values
# attributes_notifications_marketing_push             6610               34.0
# attributes_notifications_marketing_email            6610               34.0

# %%
unqiue_values_table(df_rev_users)
# Out:
# Your selected dataframe has 19430 rows and 12 columns.
#                                           Unique Values  % of Total Values
# user_id                                           19430             100.00
# created_date                                      19430             100.00
# city                                               6049              31.13
# num_contacts                                        302               1.55
# birth_year                                           69               0.36
# country                                              41               0.21
# plan                                                  6               0.03
# attributes_notifications_marketing_push               3               0.02
# attributes_notifications_marketing_email              3               0.02
# user_settings_crypto_unlocked                         2               0.01
# num_referrals                                         1               0.01
# num_successful_referrals                              1               0.01

# %%
df_rev_users["attributes_notifications_marketing_push"].fillna("-1", inplace = True)
df_rev_users["attributes_notifications_marketing_email"].fillna("-1", inplace = True)
df_rev_users['created_date'] = pd.to_datetime(df_rev_users['created_date'])
df_rev_users.drop(columns=['num_referrals','num_successful_referrals'],axis=1,inplace=True)

# %%
df_rev_users.dtypes
# Out:
# user_id                                             object
# birth_year                                           int64
# country                                             object
# city                                                object
# created_date                                datetime64[ns]
# user_settings_crypto_unlocked                        int64
# plan                                                object
# attributes_notifications_marketing_push             object
# attributes_notifications_marketing_email            object
# num_contacts                                         int64
# dtype: object

# %%
df_rev_users
# Out:
#           user_id  birth_year country           city  \
# 0          user_0        1989      PL         Gdansk
# 1          user_1        1975      GB         London
# 2          user_2        1987      PL         Poznań
# 3          user_3        1994      FR          Paris
# 4          user_4        1985      GB      Beckenham
# ...           ...         ...     ...            ...
# 19425  user_19425        1994      IE         Dublin
# 19426  user_19426        1977      ES         Madrid
# 19427  user_19427        1991      PL         Kraków
# 19428  user_19428        1984      GB         London
# 19429  user_19429        1995      RO  Campia Turzii
#
#                     created_date  user_settings_crypto_unlocked      plan  \
# 0     2018-01-13 05:15:15.599466                              1  STANDARD
# 1     2018-01-29 03:38:46.676876                              0  STANDARD
# 2     2018-01-18 19:17:31.229096                              0  STANDARD
# 3     2018-01-15 18:47:56.723104                              0  STANDARD
# 4     2018-01-11 00:36:46.673673                              0  STANDARD
# ...                          ...                            ...       ...
# 19425 2018-12-14 08:20:14.700048                              0  STANDARD
# 19426 2018-12-28 05:37:36.863792                              0  STANDARD
# 19427 2018-12-23 11:07:11.611503                              0  STANDARD
# 19428 2018-12-03 14:09:34.164270                              0  STANDARD
# 19429 2018-12-07 18:07:37.384735                              0  STANDARD
#
#       attributes_notifications_marketing_push  \
# 0                                         1.0
# 1                                          -1
# 2                                         0.0
# 3                                         1.0
# 4                                          -1
# ...                                       ...
# 19425                                     1.0
# 19426                                     1.0
# 19427                                     1.0
# 19428                                      -1
# 19429                                     1.0
#
#       attributes_notifications_marketing_email  num_contacts
# 0                                          1.0             3
# 1                                           -1            21
# 2                                          0.0            21
# 3                                          0.0             0
# 4                                           -1             2
# ...                                        ...           ...
# 19425                                      1.0            17
# 19426                                      1.0             0
# 19427                                      1.0            13
# 19428                                       -1             0
# 19429                                      1.0            10
#
# [19430 rows x 10 columns]

# %% [markdown]
# ###  Transactions

# %%
missing_values_table(df_rev_transactions)
# Out:
# Your selected dataframe has 12 columns.
# There are 4 columns that have missing values.
#                        Missing Values  % of Total Values
# ea_cardholderpresence         1170594               42.7
# ea_merchant_country           1158979               42.3
# ea_merchant_city              1158794               42.3
# ea_merchant_mcc               1158658               42.3

# %%
df_rev_transactions['ea_cardholderpresence'].unique()
df_rev_transactions['ea_cardholderpresence'].fillna("UNKNOWN", inplace = True)

# %%
df_rev_transactions['ea_merchant_mcc'].fillna("-1111", inplace = True)
df_rev_transactions['ea_merchant_mcc'] = pd.to_numeric(df_rev_transactions['ea_merchant_mcc'])

# %%
df_rev_transactions['ea_merchant_country'].fillna("UNKNOWN", inplace = True)

# %%
df_rev_transactions.drop(columns=['ea_merchant_city','ea_merchant_mcc'], axis = 1,inplace = True)

# %%
unqiue_values_table(df_rev_transactions)
# Out:
# Your selected dataframe has 2740075 rows and 10 columns.
#                        Unique Values  % of Total Values
# transaction_id               2740075             100.00
# created_date                 2739658              99.98
# amount_usd                     48548               1.77
# user_id                        18766               0.68
# ea_merchant_country              199               0.01
# transactions_currency             35               0.00
# transactions_type                 10               0.00
# transactions_state                 6               0.00
# ea_cardholderpresence              3               0.00
# direction                          2               0.00

# %%
df_rev_transactions['created_date'] = pd.to_datetime(df_rev_transactions['created_date']).dt.date
#df_rev_transactions.set_index(['user_id','created_date'],inplace=True)
df_rev_transactions.head(5)
# Out:
#   transaction_id transactions_type transactions_currency  amount_usd  \
# 0  transaction_0          TRANSFER                   AED        4.55
# 1  transaction_1      CARD_PAYMENT                   AED       15.50
# 2  transaction_2      CARD_PAYMENT                   AED       43.40
# 3  transaction_3          TRANSFER                   AED    10043.01
# 4  transaction_4      CARD_PAYMENT                   AED       43.81
#
#   transactions_state ea_cardholderpresence ea_merchant_country direction  \
# 0          COMPLETED               UNKNOWN             UNKNOWN  OUTBOUND
# 1          COMPLETED                 FALSE                 ARE  OUTBOUND
# 2          COMPLETED                 FALSE                 ARE  OUTBOUND
# 3          COMPLETED               UNKNOWN             UNKNOWN  OUTBOUND
# 4          COMPLETED                 FALSE                 ARE  OUTBOUND
#
#      user_id created_date
# 0   user_898   2018-04-03
# 1  user_1652   2019-03-19
# 2  user_1652   2019-03-18
# 3  user_1652   2019-03-22
# 4  user_5509   2019-03-22

# %%
df_rev_transactions['transactions_state'].unique()
# Out:
# array(['COMPLETED', 'REVERTED', 'DECLINED', 'PENDING', 'FAILED',
#        'CANCELLED'], dtype=object)

# %% [markdown]
# ### DEVICES

# %%
missing_values_table(df_rev_devices)
# Out:
# Your selected dataframe has 2 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
unqiue_values_table(df_rev_devices)
# Out:
# Your selected dataframe has 19430 rows and 2 columns.
#          Unique Values  % of Total Values
# user_id          19430             100.00
# brand                3               0.02

# %% [markdown]
# ### NOTIFICATIONS

# %%
missing_values_table(df_rev_notifications)
# Out:
# Your selected dataframe has 5 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
unqiue_values_table(df_rev_notifications)
# Out:
# Your selected dataframe has 121813 rows and 5 columns.
#               Unique Values  % of Total Values
# created_date         121810             100.00
# user_id               18953              15.56
# reason                   17               0.01
# channel                   3               0.00
# status                    2               0.00

# %%
df_rev_notifications
# Out:
#                            reason channel status     user_id  \
# 0       REENGAGEMENT_ACTIVE_FUNDS    PUSH   SENT   user_7086
# 1       REENGAGEMENT_ACTIVE_FUNDS    PUSH   SENT   user_6598
# 2       REENGAGEMENT_ACTIVE_FUNDS    PUSH   SENT   user_4151
# 3       REENGAGEMENT_ACTIVE_FUNDS    PUSH   SENT   user_1408
# 4       REENGAGEMENT_ACTIVE_FUNDS    PUSH   SENT   user_6292
# ...                           ...     ...    ...         ...
# 121808            LOST_CARD_ORDER   EMAIL   SENT  user_12687
# 121809            LOST_CARD_ORDER   EMAIL   SENT  user_16875
# 121810            LOST_CARD_ORDER   EMAIL   SENT  user_17426
# 121811            LOST_CARD_ORDER   EMAIL   SENT  user_15880
# 121812            LOST_CARD_ORDER   EMAIL   SENT  user_11214
#
#                       created_date
# 0       2018-12-02 17:58:33.320645
# 1       2018-12-01 23:09:37.367127
# 2       2018-12-04 02:57:56.425660
# 3       2018-12-11 02:04:46.284683
# 4       2018-12-14 17:09:58.900808
# ...                            ...
# 121808  2019-05-07 12:26:28.185772
# 121809  2019-05-10 01:25:42.530159
# 121810  2019-05-09 08:42:00.245644
# 121811  2019-05-10 23:01:30.998474
# 121812  2019-05-11 04:08:43.827505
#
# [121813 rows x 5 columns]
