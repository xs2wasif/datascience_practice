# %%
import pandas as pd

# %%
df = pd.read_json ('/home/jovyan/work/data/e_commerce.json')
df.head(3)
# Out:
#    id  discount  items_price  shipping_price  payment_price  vat  total_price  \
# 0   1         0           10              10             10    0           30
# 1   2         0           10              10             10    0           30
# 2  12         0           10              10             10    0           30
#
#    shipping_method payment_method            address_owner  ...  \
# 0  شحن داخل الرياض                 Abdulrahman Alduraywish  ...
# 1  شحن داخل الرياض                 Abdulrahman Alduraywish  ...
# 2  شحن داخل الرياض                 Abdulrahman Alduraywish  ...
#
#                  created_at                updated_at  deleted_at city_name  \
# 0 2021-04-16 23:29:36+00:00 2021-04-16 23:29:36+00:00         NaT    الرياض
# 1 2021-04-16 23:33:06+00:00 2021-04-16 23:33:06+00:00         NaT    الرياض
# 2 2021-04-27 18:12:35+00:00 2021-04-27 18:12:35+00:00         NaT    الرياض
#
#   bankTransferUrl  total                                      currentStatus  \
# ...

# %%
df.describe()
# Out:
#               id  discount  items_price  shipping_price  payment_price   vat  \
# count  18.000000      18.0    18.000000            18.0      18.000000  18.0
# mean   23.277778       0.0    10.555556            10.0       1.666667   0.0
# std    11.920351       0.0     2.357023             0.0       3.834825   0.0
# min     1.000000       0.0    10.000000            10.0       0.000000   0.0
# 25%    15.250000       0.0    10.000000            10.0       0.000000   0.0
# 50%    23.500000       0.0    10.000000            10.0       0.000000   0.0
# 75%    33.750000       0.0    10.000000            10.0       0.000000   0.0
# max    38.000000       0.0    20.000000            10.0      10.000000   0.0
#
#        total_price  address_details  coupon_code  email  last_status_id  \
# count    18.000000              0.0          0.0    0.0       18.000000
# mean     22.222222              NaN          NaN    NaN        3.888889
# ...
