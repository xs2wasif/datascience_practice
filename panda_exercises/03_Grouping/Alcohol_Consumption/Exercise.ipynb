# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
round(drinks.groupby("continent").beer_servings.mean())
# Out:
# continent
# AF     61.0
# AS     37.0
# EU    194.0
# OC     90.0
# SA    175.0
# Name: beer_servings, dtype: float64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby("continent").describe().T
# Out:
# continent                                   AF          AS          EU  \
# beer_servings                count   53.000000   44.000000   45.000000
#                              mean    61.471698   37.045455  193.777778
#                              std     80.557816   49.469725   99.631569
#                              min      0.000000    0.000000    0.000000
#                              25%     15.000000    4.250000  127.000000
#                              50%     32.000000   17.500000  219.000000
#                              75%     76.000000   60.500000  270.000000
#                              max    376.000000  247.000000  361.000000
# spirit_servings              count   53.000000   44.000000   45.000000
#                              mean    16.339623   60.840909  132.555556
#                              std     28.102794   84.362160   77.589115
#                              min      0.000000    0.000000    0.000000
# ...

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
temp = drinks.groupby(['continent']).agg({'total_litres_of_pure_alcohol':'mean'})

# %%
temp.stack()
# Out:
# continent
# AF         total_litres_of_pure_alcohol    3.007547
# AS         total_litres_of_pure_alcohol    2.170455
# EU         total_litres_of_pure_alcohol    8.617778
# OC         total_litres_of_pure_alcohol    3.381250
# SA         total_litres_of_pure_alcohol    6.308333
# dtype: float64

# %%
temp.unstack()
# Out:
#                               continent
# total_litres_of_pure_alcohol  AF           3.007547
#                               AS           2.170455
#                               EU           8.617778
#                               OC           3.381250
#                               SA           6.308333
# dtype: float64

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
temp = drinks.groupby('continent').agg(['mean', 'min', 'max'])

# %%
temp.unstack().reset_index()
# Out:
#                          level_0 level_1 continent           0
# 0                  beer_servings    mean        AF   61.471698
# 1                  beer_servings    mean        AS   37.045455
# 2                  beer_servings    mean        EU  193.777778
# 3                  beer_servings    mean        OC   89.687500
# 4                  beer_servings    mean        SA  175.083333
# 5                  beer_servings     min        AF    0.000000
# 6                  beer_servings     min        AS    0.000000
# 7                  beer_servings     min        EU    0.000000
# 8                  beer_servings     min        OC    0.000000
# 9                  beer_servings     min        SA   93.000000
# 10                 beer_servings     max        AF  376.000000
# 11                 beer_servings     max        AS  247.000000
# 12                 beer_servings     max        EU  361.000000
# 13                 beer_servings     max        OC  306.000000
# ...

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame
